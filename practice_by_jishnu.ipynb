# %% [markdown]
# <a href="https://colab.research.google.com/github/adilurahman/test/blob/main/practice_by_jishnu.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Q1. Write a function that return the range (maximum and minimun) of a given list of numbers

# %%
list1=list(input("enter your list"))
print("your list is:",list1)
print("maximum of the number: ",max(list1))
print("minimum number :",min(list1))
# Out:
# enter your list2345678
# your list is: ['2', '3', '4', '5', '6', '7', '8']
# maximum of the number:  8
# minimum number : 2

# %%
def find_range(list1):
  minimum_value=list1[0]
  #set 0 index the minimum value
  maximum_value=list1[0]
  #set 0 indexed value as a maximum value
  for i in list1:
    if(i >= maximum_value):
      maximum_value=i

    if(i <= minimum_value):
      minimum_value=i

  return (minimum_value, maximum_value)


list1=[2,3,5,65,77,7]
range=find_range(list1)
print("maximum and minimum value:",range)
# Out:
# maximum and minimum value: (2, 77)

# %% [markdown]
# # Q2. Write function that returns mean value of a list of numbers

# %%
lst= [2,4,6,8,3,5]
mean=sum(lst) / len(lst)
print("mean value :" ,mean)
# Out:
# mean value : 4.666666666666667

# %%
def mean(list_name):
  first_number=list_name[0]
  sum=0

  for number in list_name:

    sum=number+sum
  a=len(list_name)
  mean=sum/a
  return(mean)

my_list=[3,5,6,7,8,2,]
mean=mean(my_list)
print("mean=",mean)
# Out:
# mean= 5.166666666666667

# %% [markdown]
# # Q3. Write a function that returns the median value of a list of numbers

# %%
li=[2,3,4,45,6,7]
n=len(li)
if n/2==0:
  median=li[n //2]

else :
  median = (li[n // 2 - 1] + li[n // 2]) / 2

print("median of the numbers   :", median)
# Out:
# median of the numbers   : 24.5

# %%
def median(list_name):
  list_name.sort()
  n=len(list_name)

  if n/2 == 0:
    median=n

# %% [markdown]
# ## Q4. Write a function to return the mod of a list of numbers, if no mod exists, it should return None. If more than one mod exist, return the mod values as list

# %%
lst1=list(input("enter your list"))
mode=max(

# %% [markdown]
# ## Q5. Write function to compute a given percentile value (e.g. 90th percentile) of a list of numbers

# %% [markdown]
# # Q6. Write a function that returns the lower bound of a list of numbers

# %%
list3=list(input("enter your list :"))
#print(list3)
lower_bond=min(list3)
print("Lower Bond of the list :",lower_bond)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipython-input-529575865.py in <cell line: 0>()
# ----> 1 list3=list(input("enter your list :"))
#       2 #print(list3)
#       3 lower_bond=min(list3)
#       4 print("Lower Bond of the list :",lower_bond)
#
# /usr/local/lib/python3.12/dist-packages/ipykernel/kernelbase.py in raw_input(self, prompt)
#    1175                 "raw_input was called, but this frontend does not support input requests."
#    1176             )
# -> 1177         return self._input_request(
#    1178             str(prompt),
#    1179             self._parent_ident["shell"],
#
# /usr/local/lib/python3.12/dist-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#    1217             except KeyboardInterrupt:
#    1218                 # re-raise KeyboardInterrupt, to truncate traceback
# -> 1219                 raise KeyboardInterrupt("Interrupted by user") from None
#    1220             except Exception:
#    1221                 self.log.warning("Invalid Message:", exc_info=True)
#
# KeyboardInterrupt: Interrupted by user

# %%
def lower_bond(list_name):
  minimum_value=list_name[0]
  #set 0nindexed value as minimum value
  for i in list_name:
     if i <= minimum_value:
      minimum_value=i

  return(minimum_value)
list3=[1,2,3,4,5,6]
lower=lower_bond(list3)
print("lower bond of the list:",lower)
# Out:
# lower bond of the list: 1

# %% [markdown]
# ## Q7. Write function to return any outliers from a given list of numbers, if no outliers present it should return None

# %% [markdown]
# ##Q8. Write a function to return standard deviation of a list of numbers

# %% [markdown]
# ## Q9. Write function to compute and return Z-score values of a list of numbers

# %% [markdown]
# ## Q10. Write a function to compute and return the Pearson correlation coefficient value of two list of numbers
